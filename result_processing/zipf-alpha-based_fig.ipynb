# %%
import os
import re
import numpy as np
import pandas as pd
import pickle
import matplotlib
import matplotlib.pyplot as plt
import json
from result_parser import get_exp_result
from utils.distribution import distr_profile


#fig_width = 10
#plt.rcParams["figure.figsize"] = (fig_width, 6)
#plt.rcParams['font.size'] = 22

# %%
data_distr = 'zipf' # htail, cus
VI = 3
epoch = 500
fig_zoom = 0.3
n_clients = 100

# compare over datasets
acc_threshold = 95
x_labels = [0.5, 1, 1.5, 2, 2.5]
y_labels = ['Final Accuracy (%)',
            'Epoch to Accuracy',
            'Time to Accuracy (sec)']
y_lim = [80, epoch, 4000]
'''
y_labels = ['Final Accuracy(%)',
            'Epoch to Reach {}% Best Acc'.format(acc_threshold),
            'Time to Reach {}% Best Acc'.format(acc_threshold)]
'''
legends = {'fedavg':'FedAvg', 'oort_e0.8':'Oort', 'algo3_deg1_e0.8_wof100':'Fedcism'}
textures = ['xx', '//', None]

for dataset in ['cifar10']:
    for shard_per_user in [2]:
        for frac in [0.05]:
        
            # new fig set
            metrics = {'ACC':[], 'ETA':[], 'TTA':[]}
            for alpha in x_labels:
                bacc_stack = []
                TTAe_stack = []
                TTAt_stack = []

                for RUN in range(3):
                    if alpha == 1:
                        data_distr_file = '{}_dict_users_vi{}_r{}.pkl'.format(data_distr, VI, RUN)
                        result_folder = 'cossim_{}_vi{}_r{}'.format(data_distr, VI, RUN)
                    else:
                        data_distr_file = '{}_dict_users_vi{}_a{}_r{}.pkl'.format(data_distr, VI, alpha, RUN)
                        result_folder = 'cossim_{}_vi{}_a{}_r{}'.format(data_distr, VI, alpha, RUN)

                    algos, color_algos, bacc_algos, required_time = get_exp_result(
                    dataset, data_distr, VI, RUN, data_distr_file, result_folder, legends,
                    shard_per_user, frac, acc_threshold, num_users=n_clients, global_ep=epoch,
                    show_fig=False, save=False)

                    bacc_stack.append(bacc_algos)
                    TTAe_stack.append(required_time['epoch'])
                    TTAt_stack.append(required_time['time_simu'])

                metrics['ACC'].append(bacc_stack)
                metrics['ETA'].append(TTAe_stack)
                metrics['TTA'].append(TTAt_stack)

            # summary 
            x = np.arange(len(x_labels))
            for i, (k, v) in enumerate(metrics.items()):
                fig, ax = plt.subplots(figsize=(16*fig_zoom, 9*fig_zoom))
                if data_distr == 'cus': # alias
                    fig_name = '{}_{}_xa_vi{}_s{}'.format(k, 'sparsez', VI, shard_per_user)
                else:            
                    fig_name = '{}_{}_xa_vi{}_s{}'.format(k, data_distr, VI, shard_per_user)
                fig_path = os.path.join('save', dataset, 'fig', fig_name)

                #plt.title(fig_name, y=1.1)

                cur_algos = algos
                cur_v_T = v_T = np.array(v).T
                if 'TA' in k:
                    cur_algos = algos[1:]
                    cur_v_T = v_T[1:] # [algo][run][data_config]
                for aidx, algo in enumerate(cur_algos):
                    w = 0.9/len(cur_algos)
                    y_avg = cur_v_T[aidx].mean(axis=0)
                    y_max = cur_v_T[aidx].max(axis=0)
                    y_min = cur_v_T[aidx].min(axis=0)
                    y_err = np.vstack((y_max-y_avg, y_avg-y_min))

                    if k == 'ACC':
                        p = ax.bar(x+aidx*w-0.45+w/2, y_avg, yerr=y_err, 
                                    label=legends[algo], width=w,
                                    capsize=4, hatch=textures[aidx])
                        if aidx == 1:
                            base_yavg = y_avg
                        elif aidx == 2:
                            txt = ['{:.2f}x'.format(x) for x in y_avg/base_yavg]
                            ax.bar_label(p, labels=txt, padding=5, fontsize=8)
                    else:
                        p = ax.bar(x+aidx*w-0.45+w/2, y_avg, yerr=y_err, 
                                    label=legends[algo], width=w, color=color_algos[aidx+1],
                                    capsize=4, hatch=textures[aidx+1])

                        if aidx == 0:
                            base_yavg = y_avg
                        elif aidx == 1:
                            txt = ['{:.2f}x'.format(x) for x in base_yavg/y_avg]
                            ax.bar_label(p, labels=txt, padding=5, fontsize=8)

                ax.set_ylabel(y_labels[i])
                ax.set_xlabel('Exponent of Zipf $\\alpha$')
                ax.set_ylim(top=y_lim[i])
                ax.set_xticks(x, labels=x_labels)#, rotation='vertical')
                #fig.legend(fancybox=True, shadow=True, fontsize=16,
                #                      loc='lower left', bbox_to_anchor=(1, 0))
                ax.legend(fontsize=8, ncol=len(cur_algos), frameon=False)

                # Hide the right and top spines
                ax.spines['right'].set_visible(False)
                ax.spines['top'].set_visible(False)

                fig.tight_layout()
                fig.savefig('{}.{}'.format(fig_path, 'png'), format='png', transparent=True)
                fig.savefig('{}.{}'.format(fig_path, 'eps'), format='eps', transparent=True)
# Out:
# === cifar10 - cossim_zipf_vi3_a0.5_r0 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [42.97, 49.04, 51.11] -> max: 49.04
# target_acc: 46.58800, 95% of bacc
#
# required epoch
# [-1, 199, 199]
# ['-199.00x', '1.00x', '1.00x']
# required time_simu
# [-1, 1066.0, 1066.0]
# ['-1066.00x', '1.00x', '1.00x']
#
# === cifar10 - cossim_zipf_vi3_a0.5_r1 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [42.64, 53.21, 52.41] -> max: 52.41
# target_acc: 49.78950, 95% of bacc
#
# required epoch
# [-1, 225, 208]
# ['-225.00x', '1.00x', '1.08x']
# required time_simu
# [-1, 1295.0, 1195.0]
# ['-1295.00x', '1.00x', '1.08x']
#
# === cifar10 - cossim_zipf_vi3_a0.5_r2 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [43.0, 49.29, 50.19] -> max: 49.29
# target_acc: 46.82550, 95% of bacc
#
# required epoch
# [-1, 302, 296]
# ['-302.00x', '1.00x', '1.02x']
# required time_simu
# [-1, 1667.0, 1637.0]
# ['-1667.00x', '1.00x', '1.02x']
#
# === cifar10 - cossim_zipf_vi3_r0 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [37.76, 50.85, 51.75] -> max: 50.85
# target_acc: 48.30750, 95% of bacc
#
# required epoch
# [-1, 375, 227]
# ['-375.00x', '1.00x', '1.65x']
# required time_simu
# [-1, 2002.0, 1224.0]
# ['-2002.00x', '1.00x', '1.64x']
#
# === cifar10 - cossim_zipf_vi3_r1 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [37.14, 45.76, 51.18] -> max: 45.76
# target_acc: 43.47200, 95% of bacc
#
# required epoch
# [-1, 354, 303]
# ['-354.00x', '1.00x', '1.17x']
# required time_simu
# [-1, 1961.0, 1667.0]
# ['-1961.00x', '1.00x', '1.18x']
#
# === cifar10 - cossim_zipf_vi3_r2 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [38.64, 49.78, 50.88] -> max: 49.78
# target_acc: 47.29100, 95% of bacc
#
# required epoch
# [-1, 280, 210]
# ['-280.00x', '1.00x', '1.33x']
# required time_simu
# [-1, 1553.0, 1174.0]
# ['-1553.00x', '1.00x', '1.32x']
#
# === cifar10 - cossim_zipf_vi3_a1.5_r0 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [33.05, 44.36, 43.87] -> max: 43.87
# target_acc: 41.67650, 95% of bacc
#
# required epoch
# [-1, 364, 297]
# ['-364.00x', '1.00x', '1.23x']
# required time_simu
# [-1, 2162.0, 1732.0]
# ['-2162.00x', '1.00x', '1.25x']
#
# === cifar10 - cossim_zipf_vi3_a1.5_r1 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [30.78, 45.36, 45.34] -> max: 45.34
# target_acc: 43.07300, 95% of bacc
#
# required epoch
# [-1, 408, 359]
# ['-408.00x', '1.00x', '1.14x']
# required time_simu
# [-1, 2387.0, 2093.0]
# ['-2387.00x', '1.00x', '1.14x']
#
# === cifar10 - cossim_zipf_vi3_a1.5_r2 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [31.51, 44.45, 48.2] -> max: 44.45
# target_acc: 42.22750, 95% of bacc
#
# required epoch
# [-1, 306, 201]
# ['-306.00x', '1.00x', '1.52x']
# required time_simu
# [-1, 1712.0, 1125.0]
# ['-1712.00x', '1.00x', '1.52x']
#
# === cifar10 - cossim_zipf_vi3_a2_r0 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [29.55, 37.32, 38.5] -> max: 37.32
# target_acc: 35.45400, 95% of bacc
#
# required epoch
# [-1, 313, 261]
# ['-313.00x', '1.00x', '1.20x']
# required time_simu
# [-1, 1718.0, 1465.0]
# ['-1718.00x', '1.00x', '1.17x']
#
# === cifar10 - cossim_zipf_vi3_a2_r1 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [22.91, 39.74, 39.39] -> max: 39.39
# target_acc: 37.42050, 95% of bacc
#
# required epoch
# [-1, 316, 338]
# ['-338.00x', '1.07x', '1.00x']
# required time_simu
# [-1, 1770.0, 1914.0]
# ['-1914.00x', '1.08x', '1.00x']
#
# === cifar10 - cossim_zipf_vi3_a2_r2 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [31.88, 41.43, 42.6] -> max: 41.43
# target_acc: 39.35850, 95% of bacc
#
# required epoch
# [-1, 328, 320]
# ['-328.00x', '1.00x', '1.02x']
# required time_simu
# [-1, 1767.0, 1759.0]
# ['-1767.00x', '1.00x', '1.00x']
#
# === cifar10 - cossim_zipf_vi3_a2.5_r0 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [23.73, 37.11, 35.14] -> max: 35.14
# target_acc: 33.38300, 95% of bacc
#
# required epoch
# [-1, 307, 365]
# ['-365.00x', '1.19x', '1.00x']
# required time_simu
# [-1, 1713.0, 2074.0]
# ['-2074.00x', '1.21x', '1.00x']
#
# === cifar10 - cossim_zipf_vi3_a2.5_r1 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [23.34, 34.92, 35.66] -> max: 34.92
# target_acc: 33.17400, 95% of bacc
#
# required epoch
# [-1, 275, 352]
# ['-352.00x', '1.28x', '1.00x']
# required time_simu
# [-1, 1377.0, 1785.0]
# ['-1785.00x', '1.30x', '1.00x']
#
# === cifar10 - cossim_zipf_vi3_a2.5_r2 - shard2 - select100*0.05 ===
# algorithms
# ['fedavg', 'oort_e0.8', 'algo3_deg1_e0.8_wof100']
#
# bacc summary: [25.58, 33.97, 37.97] -> max: 33.97
# target_acc: 32.27150, 95% of bacc
#
# required epoch
# [-1, 439, 340]
# ['-439.00x', '1.00x', '1.29x']
# required time_simu
# [-1, 2638.0, 2022.0]
# ['-2638.00x', '1.00x', '1.30x']
